# %%
# !pip install ultralytics

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 860A-E6B1
#
#  Directory of C:\Users\Alvaro\PycharmProjects\copiloto-virtual\traffic-sign-recognition\notebooks
#
# 13/03/2025  11:13 p. m.    <DIR>          .
# 13/03/2025  02:07 p. m.    <DIR>          ..
# 13/02/2025  03:16 p. m.            36,639 aumento_de_datos.ipynb
# 13/03/2025  11:13 p. m.             1,334 benchmark.ipynb
# 13/03/2025  11:10 p. m.             3,734 benchmarks.log
# 13/03/2025  11:08 p. m.         3,932,288 calibration_image_sample_data_20x128x128x3_float32.npy
# 13/03/2025  09:12 p. m.           117,664 copiloto_virtual_logs.ipynb
# 13/03/2025  09:14 p. m.            73,347 ETL.ipynb
# 13/02/2025  03:04 p. m.         2,469,206 extract_metadata_from_dataset.ipynb
# 13/03/2025  06:06 p. m.         7,924,127 local-train_yolov10_object_detection_on_custom_dataset_with_augmented_data.ipynb
# ...

# %%
# !yolo benchmark model='../resultados/YOLO11/300_epochs/weights/best.pt' data='../dataset/processed/yolo_signals_cbba/data.yaml' imgsz=640 half=False device=0
# Out:
# ERROR â�Œï¸� Benchmark failure for PyTorch:
# Dataset '../dataset/processed/yolo_signals_cbba/data.yaml' images not found âš ï¸�, missing path 'C:\Users\Alvaro\PycharmProjects\copilotoVirtual\notebooks\dataset\processed\yolo_signals_cbba\val\images'
# Note dataset download directory is 'C:\Users\Alvaro\PycharmProjects\copilotoVirtual\notebooks\datasets'. You can update this in 'C:\Users\Alvaro\AppData\Roaming\Ultralytics\settings.json'
#
# PyTorch: starting from '..\resultados\YOLO11\300_epochs\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 19, 8400) (5.2 MB)
#
# TorchScript: starting export with torch 2.6.0+cu126...
# TorchScript: export success âœ… 1.7s, saved as '..\resultados\YOLO11\300_epochs\weights\best.torchscript' (10.4 MB)
#
# Export complete (1.7s)
# Results saved to C:\Users\Alvaro\PycharmProjects\copiloto-virtual\traffic-sign-recognition\resultados\YOLO11\300_epochs\weights
# ...
