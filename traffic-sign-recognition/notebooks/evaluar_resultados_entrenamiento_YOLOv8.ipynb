# %%
import pandas as pd

# %%
# Cargar nuevamente el archivo CSV
file_path = "../resultados/YOLOv8/300_epochs/results.csv"
df = pd.read_csv(file_path)

# Limpiar los nombres de las columnas eliminando espacios extra
df.columns = df.columns.str.strip()

# Mostrar las primeras filas para verificar los datos
df.head()
# Out:
#    epoch  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1          1.3798          4.2072          1.0634
# 1      2          1.3436          2.6974          1.0590
# 2      3          1.3537          2.1163          1.0749
# 3      4          1.4106          1.6656          1.1267
# 4      5          1.3741          1.2881          1.1239
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.51899            0.32481           0.27455
# 1               0.68034            0.32799           0.38173
# 2               0.35341            0.55652           0.44226
# 3               0.46081            0.45385           0.43357
# 4               0.56452            0.41962           0.47441
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.19021        1.0465        1.3108       0.92805  0.003322
# 1              0.24506        1.1219        1.0751       0.98248  0.006634
# 2              0.29575        1.1405        1.2484       0.99374  0.009923
# 3              0.29276        1.1843        1.0235       1.02140  0.009901
# 4              0.34326        1.1282        0.9680       1.00120  0.009868
#
#      lr/pg1    lr/pg2
# 0  0.003322  0.003322
# 1  0.006634  0.006634
# 2  0.009923  0.009923
# 3  0.009901  0.009901
# 4  0.009868  0.009868

# %%
import matplotlib.pyplot as plt

# Graficar la evolución de las métricas de entrenamiento y validación

plt.figure(figsize=(18, 8))

# Pérdidas de entrenamiento y validación
plt.subplot(1, 2, 1)
plt.plot(df["epoch"], df["train/box_loss"], label="train/box_loss")
plt.plot(df["epoch"], df["train/cls_loss"], label="train/cls_loss")
plt.plot(df["epoch"], df["train/dfl_loss"], label="train/dfl_loss")
plt.xlabel("Época")
plt.ylabel("Pérdida")
plt.title("Evolución de la pérdida - Entrenamiento")
plt.axvline(x=49, color='red', linestyle='--', label="Época 49")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(df["epoch"], df["val/box_loss"], label="val/box_loss")
plt.plot(df["epoch"], df["val/cls_loss"], label="val/cls_loss")
plt.plot(df["epoch"], df["val/dfl_loss"], label="val/dfl_loss")
plt.xlabel("Época")
plt.ylabel("Pérdida")
plt.title("Evolución de la pérdida - Validación")
plt.axvline(x=49, color='red', linestyle='--', label="Época 49")
plt.legend()



plt.show()

# Graficar la evolución de precisión, recall y mAP
plt.figure(figsize=(18, 8))

plt.subplot(1, 3, 1)
plt.plot(df["epoch"], df["metrics/precision(B)"], label="Precisión")
plt.xlabel("Época")
plt.ylabel("Precisión")
plt.title("Evolución de la Precisión")
plt.axvline(x=49, color='red', linestyle='--', label="Época 49")

plt.legend()

plt.subplot(1, 3, 2)
plt.plot(df["epoch"], df["metrics/recall(B)"], label="Recall")
plt.xlabel("Época")
plt.ylabel("Recall")
plt.title("Evolución del Recall")
plt.axvline(x=49, color='red', linestyle='--', label="Época 49")
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(df["epoch"], df["metrics/mAP50(B)"], label="mAP@0.5")
plt.plot(df["epoch"], df["metrics/mAP50-95(B)"], label="mAP@0.5:0.95")
plt.xlabel("Época")
plt.ylabel("mAP")
plt.title("Evolución de mAP")
plt.axvline(x=49, color='red', linestyle='--', label="Época 49")
plt.legend()

plt.show()
